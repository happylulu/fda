# %%
# the goal of this is to just run different queries to the FDA API
# access: https://open.fda.gov/api

import requests
import json
#import cnfg
import pprint
import pymongo 
import time

# %%
client = pymongo.MongoClient("mongodb+srv://weilu:Finish2020@fda-ue7sa.mongodb.net/adverseevents?retryWrites=true&w=majority")
events = client.drug.datafinal

# %%
events
# Out:
# Collection(Database(MongoClient(host=['fda-shard-00-01-ue7sa.mongodb.net:27017', 'fda-shard-00-02-ue7sa.mongodb.net:27017', 'fda-shard-00-00-ue7sa.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='fda-shard-0', ssl=True), 'drug'), 'datafinal')

# %%
print("starting the adverse events extraction...")

years1 = ['2019', '2020']
#years2 = ['2018', '2019', '2020']
months = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

starts = ['01', '15']
ends = ['14', '31', '14', '28','14','31','14','30','14','31','14','30','14','31','14','31','14','30','14','31','14','30','14','31']

loops = 0
for year in years1:
    print("starting year " + str(year))
    count = 0
    for month in months:
        print("starting month " + str(month))
        for ind, start in enumerate(starts):
            try:
                check = requests.get("https://api.fda.gov/drug/event.json?api_key=5kwjEEjXcPZW6ipPfHMHs4SFf3IMCTETBvFOcO3l&search=receivedate:["+year+month+start+'+TO+'+year+month+ends[count]+"]&limit=1&skip={}".format(j))
                total= check.json()['meta']['results']['total']
            except:
                print("json not good on: "+year+month+start+'TO'+year+month+ends[count])

            for i in range(0,total//100+1):
                j = str(i*100)
                if loops % 240 == 0:
                    print("done with: " + str(loops))
                    time.sleep(30)
                try:
                    response = requests.get("https://api.fda.gov/drug/event.json?api_key=5kwjEEjXcPZW6ipPfHMHs4SFf3IMCTETBvFOcO3l&search=receivedate:["+year+month+start+'+TO+'+year+month+ends[count]+"]&limit=100&skip={}".format(j))
                    events.insert_many(response.json()['results'])
                except:
                    print("json not good on: "+year+month+start+'TO'+year+month+ends[count])
                loops +=1
            count +=1
# Out:
# starting the adverse events extraction...
# starting year 2019
# starting month 01
# done with: 0
# done with: 240
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190101TO20190114
# json not good on: 20190115TO20190131
# json not good on: 20190115TO20190131
# json not good on: 20190115TO20190131
# json not good on: 20190115TO20190131
# done with: 480

# %%
j=0
response = requests.get("https://api.fda.gov/drug/event.json?api_key=5kwjEEjXcPZW6ipPfHMHs4SFf3IMCTETBvFOcO3l&search=receivedate:["+'2020'+'01'+'14'+'+TO+'+'2020'+'01'+'31'+"]&limit=100&skip={}".format(j))

# %%
102//100
# Out:
# 1
