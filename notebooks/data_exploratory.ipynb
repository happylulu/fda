# %% [markdown]
# #data_explorotary analysis

# %%
## read data from MongoDB
# the goal of this is to extract the data from MongoDB and flatten the data into desired format
# access: https://open.fda.gov/api

import requests
import json
#import cnfg
import pprint
import pymongo 
import time

# %%
client = pymongo.MongoClient("mongodb+srv://weilu:Finish2020@fda-ue7sa.mongodb.net/adverseevents?retryWrites=true&w=majority")
events = client.drug.datafinal2019

# %%
cursor_events = list(events.find({})[0:10])

# %%
 
[k.get("drugcharacterization",None) for k in cursor_events[0]['patient']['drug']]
# Out:
# ['1', '1', '1', '1']

# %%
cursor_events[0]['patient']['drug'][0].get("drugcharacterization",None)
# Out:
# '1'

# %%
## we want adverse events reaction and disease area(drug indication)

# %%
cursor_events[0]['patient']['reaction']
# Out:
# [{'reactionmeddraversionpt': '21.1',
#   'reactionmeddrapt': 'White blood cell count decreased',
#   'reactionoutcome': '1'},
#  {'reactionmeddraversionpt': '21.1',
#   'reactionmeddrapt': 'Pyrexia',
#   'reactionoutcome': '1'}]

# %%
import pandas as pd
dfItem = pd.DataFrame(cursor_events[1]['patient']['reaction'])

# %%
cursor_events = list(events.find({})[num:num_500])

# %%
i=cursor_events[0]
dfItem = pd.DataFrame(i['patient']['drug'])
dfItem['safetyreportid'] = i['safetyreportid']
dfItem['primarysourcecountry'] = i['primarysourcecountry']
dfItem['patientonsetage'] = i['patient']['patientonsetage']
dfItem['patientsex'] = i['patient']['patientsex']
dfItem['receivedate']=i['receivedate']

# %%
num=0

# %%
## get the reaction data fir
for i in range(2,134):
        tracker = i

        """ num and num_500 are how I am going to iterate through the
        cursor by taking slices """

        num = i*500
        num_500 = num + 500
        cursor_events = list(events.find({})[num:num_500])
        data_reaction_list = []
        for i in cursor_events:
            try:
                dfItem = pd.DataFrame(i['patient']['drug'])
                dfItem['safetyreportid'] = i['safetyreportid']
                dfItem['primarysourcecountry'] = i.get('primarysourcecountry',None)
                dfItem['patientonsetage'] = i['patient'].get('patientonsetage',None)
                dfItem['patientsex'] = i['patient'].get('patientsex',None)
                dfItem['receivedate']=i['receivedate']
            except:
                print('data is not good')
            data_reaction_list.append(dfItem)
        print ("done with data step: " + str(tracker))
        final_data_reaction = pd.concat(data_reaction_list)
        final_data_reaction.to_csv("../data/drug/patients"+"_"+str(tracker)+".csv")
        print( "done with csv step: " + str(tracker))
# Out:
# done with data step: 2
# done with csv step: 2
# done with data step: 3
# done with csv step: 3
# done with data step: 4
# done with csv step: 4
# done with data step: 5
# done with csv step: 5
# done with data step: 6
# done with csv step: 6
# done with data step: 7
# done with csv step: 7
# done with data step: 8
# done with csv step: 8
# done with data step: 9
# done with csv step: 9
# done with data step: 10
# done with csv step: 10
# done with data step: 11
# done with csv step: 11
# done with data step: 12
# done with csv step: 12
# done with data step: 13
# done with csv step: 13
# done with data step: 14
# done with csv step: 14
# done with data step: 15
# done with csv step: 15
# done with data step: 16
# done with csv step: 16
# done with data step: 17
# done with csv step: 17
# done with data step: 18
# done with csv step: 18
# done with data step: 19
# done with csv step: 19
# done with data step: 20
# done with csv step: 20
# done with data step: 21
# ...

# %%
## get the reaction data first
for i in range(0,134):
        tracker = i

        """ num and num_500 are how I am going to iterate through the
        cursor by taking slices """

        num = i*500
        num_500 = num + 500
        cursor_events = list(events.find({})[num:num_500])
        data_reaction_list = []
        for i in cursor_events:
            try:
                dfItem = pd.DataFrame(i['patient']['reaction'])
                dfItem['safetyreportid'] = i['safetyreportid']
            except:
                print('data is not good')
            data_reaction_list.append(dfItem)
        print ("done with data step: " + str(tracker))
        final_data_reaction = pd.concat(data_reaction_list)
        final_data_reaction.to_csv("../data/reaction/patients"+"_"+str(tracker)+".csv")
        print( "done with csv step: " + str(tracker))
# Out:
# done with data step: 0
# done with csv step: 0
# done with data step: 1
# done with csv step: 1
# done with data step: 2
# done with csv step: 2
# done with data step: 3
# done with csv step: 3
# done with data step: 4
# done with csv step: 4
# done with data step: 5
# done with csv step: 5
# done with data step: 6
# done with csv step: 6
# done with data step: 7
# done with csv step: 7
# done with data step: 8
# done with csv step: 8
# done with data step: 9
# done with csv step: 9
# done with data step: 10
# done with csv step: 10
# done with data step: 11
# done with csv step: 11
# done with data step: 12
# done with csv step: 12
# done with data step: 13
# done with csv step: 13
# done with data step: 14
# done with csv step: 14
# done with data step: 15
# done with csv step: 15
# done with data step: 16
# done with csv step: 16
# done with data step: 17
# done with csv step: 17
# done with data step: 18
# done with csv step: 18
# done with data step: 19
# done with csv step: 19
# ...

# %%
final_data_reaction.to_csv("../data/reaction/patients"+"_"+str(tracker)+".csv")

# %%
final_data_reaction = pd.concat(data_reaction_list)

# %%
final_data_reaction.columns
# Out:
# Index(['drugstartdateformat', 'drugindication', 'drugintervaldosageunitnumb',
#        'drugbatchnumb', 'drugadministrationroute', 'drugstartdate',
#        'drugenddateformat', 'openfda', 'drugenddate',
#        'drugstructuredosageunit', 'medicinalproduct', 'activesubstance',
#        'drugadditional', 'drugcharacterization', 'drugstructuredosagenumb',
#        'drugintervaldosagedefinition', 'drugseparatedosagenumb', 'actiondrug',
#        'drugdosagetext', 'drugdosageform', 'drugauthorizationnumb',
#        'safetyreportid'],
#       dtype='object')

# %%
json.loads(cursor_events[0]['patient']['reaction'][0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-dfbfb80851f0> in <module>
# ----> 1 json.loads(cursor_events[0]['patient']['reaction'][0])
#
# ~\AppData\Local\Continuum\anaconda3\envs\fda\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346         if not isinstance(s, (bytes, bytearray)):
#     347             raise TypeError('the JSON object must be str, bytes or bytearray, '
# --> 348                             'not {!r}'.format(s.__class__.__name__))
#     349         s = s.decode(detect_encoding(s), 'surrogatepass')
#     350
#
# TypeError: the JSON object must be str, bytes or bytearray, not 'dict'

# %%
test = []

# headers are the headers of the list of lists file
headers = ['safetyreportid', 'primarysourcecountry', 'receivedate', 'serious', 'transmissiondate', 'medicinalproduct', 'drugcharacterization']

# the list of our keys that aren't nested
first = ['@epoch', 'receivedate', 'serious', 'transmissiondate']

# the list of the keys that are nested
second = ['medicinalproduct', 'drugcharacterization']
keys = ['medicinalproduct', 'drugcharacterization']
test.append(headers)

""" the goal is to create a list of lists. sometimes a key does
    not exist...if it doesn't, then we skip that row """

    documents_events = []
# Out:
# [{'_id': ObjectId('5ef4f87f24d11a964fb92881'),
#   'reporttype': '1',
#   'safetyreportversion': '1',
#   'receivedateformat': '102',
#   'primarysource': {'reportercountry': 'CN', 'qualification': '3'},
#   'transmissiondateformat': '102',
#   'fulfillexpeditecriteria': '1',
#   'safetyreportid': '15778743',
#   'patient': {'patientonsetage': '68',
#    'summary': {'narrativeincludeclinical': 'CASE EVENT DATE: 20181023'},
#    'reaction': [{'reactionmeddraversionpt': '21.1',
#      'reactionmeddrapt': 'White blood cell count decreased',
#      'reactionoutcome': '1'},
#     {'reactionmeddraversionpt': '21.1',
#      'reactionmeddrapt': 'Pyrexia',
#      'reactionoutcome': '1'}],
#    'patientonsetageunit': '801',
#    'patientweight': '40',
#    'patientsex': '1',
#    'drug': [{'drugstartdateformat': '102',
#      'drugindication': 'COLON CANCER',
#      'drugintervaldosageunitnumb': '1',
#      'drugbatchnumb': 'FA180115',
#      'drugadministrationroute': '042',
# ...

# %%
documents_events = []
map(lambda x: documents_events.append(x), cursor_events)

# %%
documents_events
# Out:
# []
